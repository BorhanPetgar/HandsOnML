# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import seaborn as sb

# %%
sb.set()
housing = pd.read_csv('housing.csv')
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
print(pd.DataFrame(housing.columns).T)
# Out:
#            0         1                   2            3               4  \
# 0  longitude  latitude  housing_median_age  total_rooms  total_bedrooms
#
#             5           6              7                   8                9
# 0  population  households  median_income  median_house_value  ocean_proximity

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %%
housing.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.320451   -0.296244   -0.302916      -0.119034
# total_rooms               0.930380    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907222       0.004834
# households                0.979728    0.907222    1.000000       0.013033
# median_income            -0.007723    0.004834    0.013033       1.000000
# median_house_value        0.049686   -0.024650    0.065843       0.688075
#
#                     median_house_value
# longitude                    -0.045967
# latitude                     -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049686
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %%
housing.describe().T
# Out:
#                       count           mean            std         min  \
# longitude           20640.0    -119.569704       2.003532   -124.3500
# latitude            20640.0      35.631861       2.135952     32.5400
# housing_median_age  20640.0      28.639486      12.585558      1.0000
# total_rooms         20640.0    2635.763081    2181.615252      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20640.0    1425.476744    1132.462122      3.0000
# households          20640.0     499.539680     382.329753      1.0000
# median_income       20640.0       3.870671       1.899822      0.4999
# median_house_value  20640.0  206855.816909  115395.615874  14999.0000
#
#                             25%          50%           75%          max
# longitude             -121.8000    -118.4900    -118.01000    -114.3100
# latitude                33.9300      34.2600      37.71000      41.9500
# housing_median_age      18.0000      29.0000      37.00000      52.0000
# total_rooms           1447.7500    2127.0000    3148.00000   39320.0000
# total_bedrooms         296.0000     435.0000     647.00000    6445.0000
# population             787.0000    1166.0000    1725.00000   35682.0000
# households             280.0000     409.0000     605.00000    6082.0000
# median_income            2.5634       3.5348       4.74325      15.0001
# median_house_value  119600.0000  179700.0000  264725.00000  500001.0000

# %%
def split_train_test(data=housing, test_ratio=0.2):
    shuffled_indices = np.random.permutation(len(data))
    set_size = int(test_ratio * len(data))
    train_set_indices = shuffled_indices[set_size:]
    test_set_indices = shuffled_indices[:set_size]
    return data.iloc[train_set_indices], data.iloc[test_set_indices]

# %%
split_train_test(housing, 0.2)
# Out:
# (       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#  13518    -117.35     34.09                14.0       5983.0          1224.0
#  14383    -117.24     32.74                44.0       1686.0           285.0
#  18309    -122.11     37.41                33.0       1641.0           284.0
#  17823    -121.86     37.38                15.0       2052.0           405.0
#  13320    -117.67     34.06                26.0       1592.0           429.0
#  ...          ...       ...                 ...          ...             ...
#  1982     -120.81     38.67                14.0       8396.0          1578.0
#  16103    -122.50     37.76                45.0       1673.0           377.0
#  740      -122.13     37.67                40.0       1748.0           318.0
#  1032     -120.80     38.51                23.0       1001.0           195.0
#  5520     -118.39     33.97                46.0       2198.0           352.0
#
#         population  households  median_income  median_house_value  \
#  13518      3255.0      1150.0         2.5902            111500.0
#  14383       712.0       298.0         4.0268            298600.0
#  18309       659.0       282.0         6.0884            432900.0
#  17823      1380.0       409.0         5.8686            181100.0
#  13320      1182.0       365.0         2.4583            110400.0
#  ...           ...         ...            ...                 ...
#  1982       3952.0      1474.0         3.0565            118800.0
#  16103      1078.0       393.0         3.3393            272300.0
#  740         914.0       317.0         3.8676            184000.0
#  1032        369.0       157.0         3.1250             96400.0
#  5520        839.0       335.0         6.5778            350800.0
#
#        ocean_proximity
#  13518          INLAND
#  14383      NEAR OCEAN
#  18309        NEAR BAY
#  17823       <1H OCEAN
#  13320          INLAND
#  ...               ...
#  1982           INLAND
#  16103      NEAR OCEAN
#  740          NEAR BAY
#  1032           INLAND
#  5520        <1H OCEAN
#
#  [16512 rows x 10 columns],
#         longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#  13006    -121.28     38.67                23.0       1727.0           264.0
#  19798    -123.12     40.54                23.0       1091.0           217.0
#  4030     -118.53     34.18                16.0       7194.0          1976.0
#  12531    -121.50     38.57                44.0       1375.0           351.0
#  3696     -118.37     34.21                33.0       2034.0           470.0
#  ...          ...       ...                 ...          ...             ...
#  16836    -122.49     37.60                33.0       3507.0           669.0
#  10986    -117.83     33.75                34.0       2660.0           601.0
#  14748    -117.05     32.58                25.0       2185.0           370.0
#  12473    -121.47     38.58                43.0       3807.0           952.0
#  15524    -117.04     33.15                15.0      13814.0          2888.0
#
#         population  households  median_income  median_house_value  \
#  13006       833.0       258.0         5.4797            160000.0
#  19798       539.0       201.0         1.8696             61500.0
#  4030       3687.0      1894.0         3.1887            189300.0
#  12531       766.0       321.0         2.1719             87500.0
#  3696       1990.0       423.0         3.7455            159600.0
#  ...           ...         ...            ...                 ...
#  16836      1697.0       660.0         4.0795            270600.0
#  10986      1475.0       567.0         3.4152            210200.0
#  14748      1558.0       369.0         5.3072            132700.0
#  12473      1484.0       850.0         2.3266            137500.0
#  15524      6583.0      2789.0         2.8247            150000.0
#
#        ocean_proximity
#  13006          INLAND
#  19798          INLAND
#  4030        <1H OCEAN
#  12531          INLAND
#  3696        <1H OCEAN
#  ...               ...
#  16836      NEAR OCEAN
#  10986       <1H OCEAN
#  14748      NEAR OCEAN
#  12473          INLAND
#  15524       <1H OCEAN
#
#  [4128 rows x 10 columns])

# %%
train_set, test_set = split_train_test(housing, 0.2)

# %%
np.random.seed(5)
np.random.permutation(5)
# Out:
# array([4, 0, 1, 2, 3])
